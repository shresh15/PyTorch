# %% [markdown]
# <a href="https://colab.research.google.com/github/shresh15/PyTorch/blob/main/Tensors_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
print(torch.__version__)
if torch.cuda.is_available():
  print("available gpu")

else:
  print("not available")
# Out:
# 2.9.0+cpu
# not available

# %%
# CREATE TENSOR
torch.empty(2,3)
# Out:
# tensor([[2.1715e-18, 2.3081e-12, 2.6302e+20],
#         [6.1943e-04, 3.6022e-12, 6.9989e+22]])

# %%
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %% [markdown]
# TENSOR SHAPES

# %%
x=torch.tensor([[1,2,3],[4,5,6]])
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
torch.tensor([1.3,2.5,5.9], dtype=torch.int32)
# Out:
# tensor([1, 2, 5], dtype=torch.int32)

# %%
d=torch.tensor([1.9,2.3,3.7,4.4])
torch.clamp(d, min=2,max=3)
# Out:
# tensor([2.0000, 2.3000, 3.0000, 3.0000])

# %%
  ###copy tensor
  #a=b makes the memory location same

# %%
a=torch.empty(2,3)
a
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
b=a.clone()
b
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
a[0][0]=10

# %%
a
# Out:
# tensor([[10.,  0.,  0.],
#         [ 0.,  0.,  0.]])

# %%
b
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
